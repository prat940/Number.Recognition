# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.models import Sequential
m=keras.datasets.mnist.load_data()
(x_train,y_train),(x_test,y_test)=m
x_train
x_train.shape
x_test.shape
y_train
import matplotlib.pyplot as plt
plt.imshow(x_train[56])
x_test=x_test/255
x_train=x_train/255
model=Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
h=model.fit(x_train, y_train, epochs=10, validation_split=0.2)
p=model.predict(x_test)
y_pred=p.argmax(axis=1)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
accuracy = model.evaluate(x_test, y_test)[1]
print("Test Accuracy:", accuracy)
plt.matshow(x_test[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 128)               100480
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2926 - accuracy: 0.9159 - val_loss: 0.1590 - val_accuracy: 0.9560
# Epoch 2/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1329 - accuracy: 0.9612 - val_loss: 0.1210 - val_accuracy: 0.9654
# Epoch 3/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0898 - accuracy: 0.9726 - val_loss: 0.1114 - val_accuracy: 0.9648
# Epoch 4/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0657 - accuracy: 0.9806 - val_loss: 0.0894 - val_accuracy: 0.9725
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0508 - accuracy: 0.9855 - val_loss: 0.0975 - val_accuracy: 0.9709
# Epoch 6/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0402 - accuracy: 0.9885 - val_loss: 0.0903 - val_accuracy: 0.9743
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0303 - accuracy: 0.9912 - val_loss: 0.0992 - val_accuracy: 0.9732
# Epoch 8/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0244 - accuracy: 0.9926 - val_loss: 0.0971 - val_accuracy: 0.9742
# Epoch 9/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0197 - accuracy: 0.9938 - val_loss: 0.0961 - val_accuracy: 0.9747
# Epoch 10/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.1033 - val_accuracy: 0.9740
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0792 - accuracy: 0.9769
# Test Accuracy: 0.9768999814987183

# %%
np.argmax(y_pred[1])
y_pred=model.predict(x_test)
plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
# Out:
# 313/313 [==============================] - 1s 3ms/step
